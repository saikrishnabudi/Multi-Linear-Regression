# %%
#Importing the required libraries for the dataset

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import warnings
warnings.filterwarnings("ignore")

# %%
#Reading the Data

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-879a79ee-ee39-490c-ba89-79e818dc59fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-879a79ee-ee39-490c-ba89-79e818dc59fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("/content/ToyotaCorolla (1).csv",encoding="latin1")

# %%
df
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ...  \
# ...

# %%
df.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ... Central_Lock  \
# 0         10      2002  46986    Diesel  90          1  ...            1
# 1         10      2002  72937    Diesel  90          1  ...            1
# 2          9      2002  41711    Diesel  90          1  ...            0
# 3          7      2002  48000    Diesel  90          0  ...            0
# 4          3      2002  38500    Diesel  90          0  ...            1
#
#    Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# ...

# %%
df.tail()
# Out:
#         Id                                              Model  Price  \
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ...  \
# 1431         69         12      1998  20544    Petrol   86          1  ...
# 1432         72          9      1998  19000    Petrol   86          0  ...
# 1433         71         10      1998  17016    Petrol   86          0  ...
# 1434         70         11      1998  16916    Petrol   86          1  ...
# 1435         76          5      1998      1    Petrol  110          0  ...
#
#      Central_Lock  Powered_Windows  Power_Steering  Radio  Mistlamps  \
# ...

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1436 non-null   int64
#  1   Model             1436 non-null   object
#  2   Price             1436 non-null   int64
#  3   Age_08_04         1436 non-null   int64
#  4   Mfg_Month         1436 non-null   int64
#  5   Mfg_Year          1436 non-null   int64
#  6   KM                1436 non-null   int64
#  7   Fuel_Type         1436 non-null   object
#  8   HP                1436 non-null   int64
#  9   Met_Color         1436 non-null   int64
#  10  Color             1436 non-null   object
#  11  Automatic         1436 non-null   int64
#  12  cc                1436 non-null   int64
#  13  Doors             1436 non-null   int64
#  14  Cylinders         1436 non-null   int64
#  15  Gears             1436 non-null   int64
# ...

# %%
df.size
# Out:
# 54568

# %%
df.describe()
# Out:
#                 Id         Price    Age_08_04    Mfg_Month     Mfg_Year  \
# count  1436.000000   1436.000000  1436.000000  1436.000000  1436.000000
# mean    721.555014  10730.824513    55.947075     5.548747  1999.625348
# std     416.476890   3626.964585    18.599988     3.354085     1.540722
# min       1.000000   4350.000000     1.000000     1.000000  1998.000000
# 25%     361.750000   8450.000000    44.000000     3.000000  1998.000000
# 50%     721.500000   9900.000000    61.000000     5.000000  1999.000000
# 75%    1081.250000  11950.000000    70.000000     8.000000  2001.000000
# max    1442.000000  32500.000000    80.000000    12.000000  2004.000000
#
#                   KM           HP    Met_Color    Automatic           cc  ...  \
# count    1436.000000  1436.000000  1436.000000  1436.000000   1436.00000  ...
# mean    68533.259749   101.502089     0.674791     0.055710   1576.85585  ...
# std     37506.448872    14.981080     0.468616     0.229441    424.38677  ...
# ...

# %%
df1=pd.concat([df.iloc[:,2:4],df.iloc[:,6:7],df.iloc[:,8:9],df.iloc[:,12:14],df.iloc[:,15:18]],axis=1)

# %%
df1
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
df1.describe()
# Out:
#               Price    Age_08_04             KM           HP           cc  \
# count   1436.000000  1436.000000    1436.000000  1436.000000   1436.00000
# mean   10730.824513    55.947075   68533.259749   101.502089   1576.85585
# std     3626.964585    18.599988   37506.448872    14.981080    424.38677
# min     4350.000000     1.000000       1.000000    69.000000   1300.00000
# 25%     8450.000000    44.000000   43000.000000    90.000000   1400.00000
# 50%     9900.000000    61.000000   63389.500000   110.000000   1600.00000
# 75%    11950.000000    70.000000   87020.750000   110.000000   1600.00000
# max    32500.000000    80.000000  243000.000000   192.000000  16000.00000
#
#              Doors        Gears  Quarterly_Tax      Weight
# count  1436.000000  1436.000000    1436.000000  1436.00000
# mean      4.033426     5.026462      87.122563  1072.45961
# std       0.952677     0.188510      41.128611    52.64112
# min       2.000000     3.000000      19.000000  1000.00000
# ...

# %%
#Checking the miss values

df1.isna().sum()
# Out:
# Price            0
# Age_08_04        0
# KM               0
# HP               0
# cc               0
# Doors            0
# Gears            0
# Quarterly_Tax    0
# Weight           0
# dtype: int64

# %%
#Checking the duplicate records

df1[df1.duplicated()]
# Out:
#      Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 113  24950          8  13253  116  2000      5      5            234    1320

# %%
df2=df1.drop_duplicates()

# %%
df2
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1435 rows x 9 columns]

# %%
#Renaming the columns

df3=df2.rename({"Age_08_04":"Age"},axis=1)

# %%
df3
# Out:
#       Price  Age     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500   23  46986   90  2000      3      5            210    1165
# 1     13750   23  72937   90  2000      3      5            210    1165
# 2     13950   24  41711   90  2000      3      5            210    1165
# 3     14950   26  48000   90  2000      3      5            210    1165
# 4     13750   30  38500   90  2000      3      5            210    1170
# ...     ...  ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500   69  20544   86  1300      3      5             69    1025
# 1432  10845   72  19000   86  1300      3      5             69    1015
# 1433   8500   71  17016   86  1300      3      5             69    1015
# 1434   7250   70  16916   86  1300      3      5             69    1015
# 1435   6950   76      1  110  1600      5      5             19    1114
#
# [1435 rows x 9 columns]

# %% [markdown]
# # **Correlation Analysis**

# %%
df3.corr()
# Out:
#                   Price       Age        KM        HP        cc     Doors  \
# Price          1.000000 -0.876273 -0.569420  0.314134  0.124375  0.183604
# Age           -0.876273  1.000000  0.504575 -0.155293 -0.096549 -0.146929
# KM            -0.569420  0.504575  1.000000 -0.332904  0.103822 -0.035193
# HP             0.314134 -0.155293 -0.332904  1.000000  0.035207  0.091803
# cc             0.124375 -0.096549  0.103822  0.035207  1.000000  0.079254
# Doors          0.183604 -0.146929 -0.035193  0.091803  0.079254  1.000000
# Gears          0.063831 -0.005629  0.014890  0.209642  0.014732 -0.160101
# Quarterly_Tax  0.211508 -0.193319  0.283312 -0.302287  0.305982  0.107353
# Weight         0.575869 -0.466484 -0.023969  0.087143  0.335077  0.301734
#
#                   Gears  Quarterly_Tax    Weight
# Price          0.063831       0.211508  0.575869
# Age           -0.005629      -0.193319 -0.466484
# KM             0.014890       0.283312 -0.023969
# ...

# %% [markdown]
# # **Scatterplot Between variables along with histograms**

# %%
sns.set_style(style="darkgrid")
sns.pairplot(df3)

# %% [markdown]
# # **Model Building**

# %%
model=smf.ols("Price~Age+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight",data=df3).fit()

# %% [markdown]
# # **Model Testing**

# %%
#Co-efficient of model
model.params
# Out:
# Intercept       -5472.540368
# Age              -121.713891
# KM                 -0.020737
# HP                 31.584612
# cc                 -0.118558
# Doors              -0.920189
# Gears             597.715894
# Quarterly_Tax       3.858805
# Weight             16.855470
# dtype: float64

# %%
#Summary of model

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     1118.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        15:50:44   Log-Likelihood:                -12366.
# No. Observations:                1435   AIC:                         2.475e+04
# Df Residuals:                    1426   BIC:                         2.480e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
# Since the p value for cc and Doors Spend is > 0.05 build simple linear regression and multi linear regression models  to see insignificant variables


# Build a simple linear model to check the column cc

slr_cc=smf.ols("Price~cc",data=df3).fit()

# %%
slr_cc.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     22.52
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           2.29e-06
# Time:                        15:54:02   Log-Likelihood:                -13779.
# No. Observations:                1435   AIC:                         2.756e+04
# Df Residuals:                    1433   BIC:                         2.757e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   9053.5368    363.894     24.880      0.000    8339.715    9767.359
# ...

# %%
# Build a simple linear model to check the column Doors

slr_Doors=smf.ols("Price~Doors",data=df3).fit()

# %%
slr_Doors

# %%
slr_Doors.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     49.99
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           2.40e-12
# Time:                        15:56:58   Log-Likelihood:                -13765.
# No. Observations:                1435   AIC:                         2.753e+04
# Df Residuals:                    1433   BIC:                         2.755e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7916.1452    407.596     19.422      0.000    7116.596    8715.694
# ...

# %%
# Building the Multi Linear regression model of cc and Doors together

slr_cc_Doors=smf.ols("Price~cc+Doors",data=df3).fit()
slr_cc_Doors

# %%
slr_cc_Doors.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     34.40
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           2.55e-15
# Time:                        15:59:41   Log-Likelihood:                -13756.
# No. Observations:                1435   AIC:                         2.752e+04
# Df Residuals:                    1432   BIC:                         2.753e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   6568.3395    513.700     12.786      0.000    5560.655    7576.024
# ...

# %% [markdown]
# # **Model Validation Techniques**
# There are Two Techniques
#
# 1) Collinearity Check - VIF
#
# 2) Residual Analysis
#
# Calculating Variance Inflation Factor (VIF) = 1/1-r^2

# %%
rsq_age=smf.ols("Age~KM+HP+cc++Doors+Gears+Quarterly_Tax+Weight",data=df3).fit().rsquared
vif_age=1/(1-rsq_age)
vif_age
# Out:
# 1.8762358497682892

# %%
rsq_km=smf.ols("KM~Age+HP+cc+Doors+Gears+Quarterly_Tax+Weight",data=df3).fit().rsquared
vif_km=1/(1-rsq_km)
vif_km
# Out:
# 1.75717802398104

# %%
rsq_hp=smf.ols("HP~KM+Age+cc+Doors+Gears+Quarterly_Tax+Weight",data=df3).fit().rsquared
vif_hp=1/(1-rsq_hp)
vif_hp
# Out:
# 1.4191801087182137

# %%
rsq_cc=smf.ols("cc~Age+KM+HP+Doors+Gears+Quarterly_Tax+Weight",data=df3).fit().rsquared
vif_cc=1/(1-rsq_cc)
vif_cc
# Out:
# 1.1634703645940856

# %%
rsq_doors=smf.ols("Doors~Age+KM+HP+cc+Gears+Quarterly_Tax+Weight",data=df3).fit().rsquared
vif_doors=1/(1-rsq_doors)
vif_doors
# Out:
# 1.1558898658142076

# %%
rsq_gears=smf.ols("Gears~Age+KM+HP+cc+Doors+Quarterly_Tax+Weight",data=df3).fit().rsquared
vif_gears=1/(1-rsq_gears)
vif_gears
# Out:
# 1.0988429081631148

# %%
rsq_Quarterly_Tax=smf.ols("Quarterly_Tax~Age+KM+HP+cc+Doors+Gears+Weight",data=df3).fit().rsquared
vif_Quarterly_Tax=1/(1-rsq_Quarterly_Tax)
vif_Quarterly_Tax
# Out:
# 2.295374508985715

# %%
rsq_weight=smf.ols("Weight~Age+KM+HP+cc+Doors+Gears+Quarterly_Tax",data=df3).fit().rsquared
vif_weight=1/(1-rsq_weight)
vif_weight
# Out:
# 2.4871800071791856

# %%
#Sorting the VIF values in a DataFrame

dataframe = {'Variables':['Age','KM','HP','cc','Doors','Gears','Quarterly_Tax','Weight'],'VIF':[vif_age,vif_km,vif_hp,vif_cc,vif_doors,vif_gears,vif_Quarterly_Tax,vif_weight]}
Vif_frame=pd.DataFrame(dataframe)
Vif_frame
# Out:
#        Variables       VIF
# 0            Age  1.876236
# 1             KM  1.757178
# 2             HP  1.419180
# 3             cc  1.163470
# 4          Doors  1.155890
# 5          Gears  1.098843
# 6  Quarterly_Tax  2.295375
# 7         Weight  2.487180

# %% [markdown]
# Since No value of VIF is greater than 20 , we can say that there is no collinearity problem. So we shall consider all columns for building the model
#
# # **Residual Analysis**
#
# # **Test for Normality of Residuals (Q-Q Plot)**

# %%
import statsmodels.api as sm
sns.set_style(style="darkgrid")
qqplot=sm.qqplot(model.resid,line="q")
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid<-4000))
# Out:
# [array([190, 191, 220, 392, 401, 600, 653, 959])]

# %% [markdown]
# Residual Plot for Homoscedasticity or Heteroscedasticity (plotting model's standardized fitted values vs standardized residual values)

# %%
def get_standardized_values(vals):
  return(vals-vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title("Residual Plot")
plt.xlabel("Standardized Fitted Values")
plt.ylabel("Standardized Residual Values")
plt.show()

# %% [markdown]
# Residual Vs Regressor

# %%
fig=plt.figure(figsize=(16,8))
fig=sm.graphics.plot_regress_exog(model,"Age",fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(16,8))
fig=sm.graphics.plot_regress_exog(model,"KM",fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(16,8))
fig=sm.graphics.plot_regress_exog(model,"HP",fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(16,8))
fig=sm.graphics.plot_regress_exog(model,"cc",fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(16,8))
fig=sm.graphics.plot_regress_exog(model,"Doors",fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(16,8))
fig=sm.graphics.plot_regress_exog(model,"Gears",fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(16,8))
fig=sm.graphics.plot_regress_exog(model,"Quarterly_Tax",fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(16,8))
fig=sm.graphics.plot_regress_exog(model,"Weight",fig=fig)
plt.show()

# %% [markdown]
# # **Model Deletion Diagnostics**
#
# Detecting Influencers / Outliers
#
# Cooks Distance

# %%
model_influence=model.get_influence()
(c,_)=model_influence.cooks_distance

# %%
#Plotting the influencers values using stem plot

sns.set_style(style="darkgrid")
fig=plt.subplots(figsize=(18,6))
plt.stem(np.arange(len(df3)),np.round(c,3))
plt.xlabel("Row Index")
plt.ylabel("Cooks Distamce")
plt.show()

# %%
# Index and value of influencer where C>0.5
np.argmax(c) , np.max(c)
# Out:
# (80, 78.72950582258932)

# %% [markdown]
# # **High Influence Plots**

# %%
fig,ax=plt.subplots(figsize=(15,5))
fig=influence_plot(model,ax=ax)

# %%
k=df3.shape[1]
n=df3.shape[0]
leverage_cutoff=3*((k+1)/n)
leverage_cutoff
# Out:
# 0.020905923344947737

# %%
df3[df3.index.isin([221,960,80])]
# Out:
#      Price  Age     KM   HP     cc  Doors  Gears  Quarterly_Tax  Weight
# 80   18950   25  20019  110  16000      5      5            100    1180
# 221  12450   44  74172  110   1600      5      5            163    1615
# 960   9390   66  50806   86   1300      3      5             19    1480

# %%
df3.shape
# Out:
# (1435, 9)

# %% [markdown]
# # **Improving the model**

# %%
#Discard the data points which are influencers and reasign the row number (reset_index())

df4=df3.copy()

df4=df3.drop(df3.index[[80,221,960,]],axis=0).reset_index(drop=True)
df4
# Out:
#       Price  Age     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500   23  46986   90  2000      3      5            210    1165
# 1     13750   23  72937   90  2000      3      5            210    1165
# 2     13950   24  41711   90  2000      3      5            210    1165
# 3     14950   26  48000   90  2000      3      5            210    1165
# 4     13750   30  38500   90  2000      3      5            210    1170
# ...     ...  ...    ...  ...   ...    ...    ...            ...     ...
# 1427   7500   69  20544   86  1300      3      5             69    1025
# 1428  10845   72  19000   86  1300      3      5             69    1015
# 1429   8500   71  17016   86  1300      3      5             69    1015
# 1430   7250   70  16916   86  1300      3      5             69    1015
# 1431   6950   76      1  110  1600      5      5             19    1114
#
# [1432 rows x 9 columns]

# %% [markdown]
# # **Model Deletion Diagnostics**

# %%
# Check again for influencers and Outliers

model1 = smf.ols('Price~Age+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight',data=df4).fit()
fig,ax=plt.subplots(figsize=(15,5))
fig=influence_plot(model1,ax = ax)

# %%
k=df4.shape[1]
n=df4.shape[0]
leverage_cutoff1=3*((k+1/n))
leverage_cutoff1
# Out:
# 27.00209497206704

# %%
#Discard the data points which are influencers and reasign the row number (reset_index())

df4=df4.copy()
df5=df4.drop(df4.index[[219,957,987,953]],axis=0).reset_index(drop=True)
df5
# Out:
#       Price  Age     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500   23  46986   90  2000      3      5            210    1165
# 1     13750   23  72937   90  2000      3      5            210    1165
# 2     13950   24  41711   90  2000      3      5            210    1165
# 3     14950   26  48000   90  2000      3      5            210    1165
# 4     13750   30  38500   90  2000      3      5            210    1170
# ...     ...  ...    ...  ...   ...    ...    ...            ...     ...
# 1423   7500   69  20544   86  1300      3      5             69    1025
# 1424  10845   72  19000   86  1300      3      5             69    1015
# 1425   8500   71  17016   86  1300      3      5             69    1015
# 1426   7250   70  16916   86  1300      3      5             69    1015
# 1427   6950   76      1  110  1600      5      5             19    1114
#
# [1428 rows x 9 columns]

# %% [markdown]
# # **Final Model**

# %%
Final_Model=smf.ols("Price~Age+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight",data=df5).fit()

# %%
Final_Model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.885
# Model:                            OLS   Adj. R-squared:                  0.884
# Method:                 Least Squares   F-statistic:                     1363.
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):               0.00
# Time:                        17:49:10   Log-Likelihood:                -12180.
# No. Observations:                1428   AIC:                         2.438e+04
# Df Residuals:                    1419   BIC:                         2.442e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# # **Model Predictions**

# %%
#New data for prediction

new_data=pd.DataFrame({'Age':12,"KM":40000,"HP":80,"cc":1300,"Doors":4,"Gears":5,"Quarterly_Tax":69,"Weight":1012},index=[0])
new_data
# Out:
#    Age     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0   12  40000  80  1300      4      5             69    1012

# %%
#Manual Prediction

Final_Model.predict(new_data)
# Out:
# 0    14410.990518
# dtype: float64

# %%
#Auto Predict

pred_y=Final_Model.predict(df5)
pred_y
# Out:
# 0       16335.790261
# 1       15895.513616
# 2       16313.462654
# 3       15983.122172
# 4       15850.756368
#             ...
# 1423     9119.149472
# 1424     8502.386345
# 1425     8647.867902
# 1426     8761.386098
# 1427    10660.471327
# Length: 1428, dtype: float64
